# %%
from excel_reporter import ExcelReporter
reporter = ExcelReporter()
reporter.collect_all_results()

# %%
from excel_reporter import ExcelReporter
reporter = ExcelReporter()
reporter.collect_all_results()

# %%
from excel_reporter import ExcelReporter
reporter = ExcelReporter()
reporter.collect_all_results()
reporter.generate_report()
# Out:
# INFO:excel_reporter:Найдено 4 основных файлов с результатами
# INFO:excel_reporter:  Загружена конфигурация из: my_experiment_20260331_105700_config.json
# INFO:excel_reporter:Извлеченные метрики для my_experiment_20260331_105700:
# INFO:excel_reporter:  MAP: 0.8055555555555555, MRR: 0.7777777777777777
# INFO:excel_reporter:  P@1: 0.0, P@3: 0.6666666666666666
# INFO:excel_reporter:  R@1: 0.0, R@3: 0.6666666666666666
# INFO:excel_reporter:Обработан: my_experiment_20260331_105700.json
# INFO:excel_reporter:  Загружена конфигурация из: my_experiment_20260331_110610_config.json
# INFO:excel_reporter:Извлеченные метрики для my_experiment_20260331_110610:
# INFO:excel_reporter:  MAP: 0.8055555555555555, MRR: 0.7777777777777777
# INFO:excel_reporter:  P@1: 0.0, P@3: 0.6666666666666666
# INFO:excel_reporter:  R@1: 0.0, R@3: 0.6666666666666666
# INFO:excel_reporter:Обработан: my_experiment_20260331_110610.json
# INFO:excel_reporter:  Загружена конфигурация из: my_experiment_20260331_105700_config.json
# INFO:excel_reporter:Извлеченные метрики для my_experiment_20260331_105700:
# INFO:excel_reporter:  MAP: 0.8055555555555555, MRR: 0.7777777777777777
# INFO:excel_reporter:  P@1: 0.0, P@3: 0.6666666666666666
# INFO:excel_reporter:  R@1: 0.0, R@3: 0.6666666666666666
# INFO:excel_reporter:Обработан: my_experiment_20260331_105700.json
# INFO:excel_reporter:  Загружена конфигурация из: my_experiment_20260331_110610_config.json
# INFO:excel_reporter:Извлеченные метрики для my_experiment_20260331_110610:
# INFO:excel_reporter:  MAP: 0.8055555555555555, MRR: 0.7777777777777777
# INFO:excel_reporter:  P@1: 0.0, P@3: 0.6666666666666666
# INFO:excel_reporter:  R@1: 0.0, R@3: 0.6666666666666666
# INFO:excel_reporter:Обработан: my_experiment_20260331_110610.json
# INFO:excel_reporter:📊 Начинаем генерацию Excel отчета...
# INFO:excel_reporter:Найдено 4 основных файлов с результатами
# INFO:excel_reporter:  Загружена конфигурация из: my_experiment_20260331_105700_config.json
# INFO:excel_reporter:Извлеченные метрики для my_experiment_20260331_105700:
# INFO:excel_reporter:  MAP: 0.8055555555555555, MRR: 0.7777777777777777
# INFO:excel_reporter:  P@1: 0.0, P@3: 0.6666666666666666
# INFO:excel_reporter:  R@1: 0.0, R@3: 0.6666666666666666
# INFO:excel_reporter:Обработан: my_experiment_20260331_105700.json
# INFO:excel_reporter:  Загружена конфигурация из: my_experiment_20260331_110610_config.json
# INFO:excel_reporter:Извлеченные метрики для my_experiment_20260331_110610:
# INFO:excel_reporter:  MAP: 0.8055555555555555, MRR: 0.7777777777777777
# INFO:excel_reporter:  P@1: 0.0, P@3: 0.6666666666666666
# INFO:excel_reporter:  R@1: 0.0, R@3: 0.6666666666666666
# INFO:excel_reporter:Обработан: my_experiment_20260331_110610.json
# INFO:excel_reporter:  Загружена конфигурация из: my_experiment_20260331_105700_config.json
# INFO:excel_reporter:Извлеченные метрики для my_experiment_20260331_105700:
# INFO:excel_reporter:  MAP: 0.8055555555555555, MRR: 0.7777777777777777
# INFO:excel_reporter:  P@1: 0.0, P@3: 0.6666666666666666
# INFO:excel_reporter:  R@1: 0.0, R@3: 0.6666666666666666
# INFO:excel_reporter:Обработан: my_experiment_20260331_105700.json
# INFO:excel_reporter:  Загружена конфигурация из: my_experiment_20260331_110610_config.json
# INFO:excel_reporter:Извлеченные метрики для my_experiment_20260331_110610:
# INFO:excel_reporter:  MAP: 0.8055555555555555, MRR: 0.7777777777777777
# INFO:excel_reporter:  P@1: 0.0, P@3: 0.6666666666666666
# INFO:excel_reporter:  R@1: 0.0, R@3: 0.6666666666666666
# INFO:excel_reporter:Обработан: my_experiment_20260331_110610.json
# WARNING:excel_reporter:Не удалось применить стили: 'MergedCell' object has no attribute 'column_letter'
# === Структура my_experiment_20260331_105700.json ===
# Ключи верхнего уровня: ['experiment_id', 'timestamp', 'config', 'retrieval_metrics', 'generation_metrics', 'detailed_predictions', 'execution_time', 'status', 'error_message', 'system_configuration', 'meta']
#
# retrieval_metrics keys: ['map', 'mrr', 'precision_at_k', 'recall_at_k', 'ndcg_at_k']
# precision_at_k: {'1': 0.6666666666666666, '3': 0.3333333333333333, '5': 0.26666666666666666, '10': 0.13333333333333333} (type: <class 'dict'>, length: N/A)
# recall_at_k: {'1': 0.6666666666666666, '3': 0.8333333333333334, '5': 1.0, '10': 1.0} (type: <class 'dict'>, length: N/A)
# ndcg_at_k: {'1': 0.6666666666666666, '3': 0.7688578654609097, '5': 0.8568805729851068, '10': 0.8568805729851068} (type: <class 'dict'>, length: N/A)
# ==================================================
#
# === Структура my_experiment_20260331_105700.json ===
# Ключи верхнего уровня: ['experiment_id', 'timestamp', 'config', 'retrieval_metrics', 'generation_metrics', 'detailed_predictions', 'execution_time', 'status', 'error_message', 'system_configuration', 'meta']
#
# retrieval_metrics keys: ['map', 'mrr', 'precision_at_k', 'recall_at_k', 'ndcg_at_k']
# precision_at_k: {'1': 0.6666666666666666, '3': 0.3333333333333333, '5': 0.26666666666666666, '10': 0.13333333333333333} (type: <class 'dict'>, length: N/A)
# recall_at_k: {'1': 0.6666666666666666, '3': 0.8333333333333334, '5': 1.0, '10': 1.0} (type: <class 'dict'>, length: N/A)
# ndcg_at_k: {'1': 0.6666666666666666, '3': 0.7688578654609097, '5': 0.8568805729851068, '10': 0.8568805729851068} (type: <class 'dict'>, length: N/A)
# ==================================================
# INFO:excel_reporter:✅ Excel отчет создан: experiments\experiments_summary.xlsx
# INFO:excel_reporter:
# 📈 Статистика:
# INFO:excel_reporter:  - Всего экспериментов: 4
# INFO:excel_reporter:  - Успешных: 4
# INFO:excel_reporter:  - С ошибками: 0
# WindowsPath('experiments/experiments_summary.xlsx')
